# %%
# !wget https://dcc.ligo.org/public/0168/P2000217/002/O3aSensitivity.tar.gz
# Out:
# --2021-04-09 10:22:15--  https://dcc.ligo.org/public/0168/P2000217/002/O3aSensitivity.tar.gz
# Resolving dcc.ligo.org (dcc.ligo.org)... 131.215.125.144
# Connecting to dcc.ligo.org (dcc.ligo.org)|131.215.125.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8284891 (7.9M) [application/x-gzip]
# Saving to: ‘O3aSensitivity.tar.gz’
#
# 100%[======================================>] 8,284,891   --.-K/s   in 0.1s
#
# 2021-04-09 10:22:15 (70.0 MB/s) - ‘O3aSensitivity.tar.gz’ saved [8284891/8284891]

# %%
# !tar -xvzf O3aSensitivity.tar.gz
# Out:
# O3aSensitivity/
# O3aSensitivity/.gitattributes
# O3aSensitivity/.gitignore
# O3aSensitivity/LICENSE
# O3aSensitivity/README.md
# O3aSensitivity/SensitivityTutorial.ipynb
# O3aSensitivity/environment.yml
# O3aSensitivity/o3a_bbhpop_inj_info.hdf

# %%
# !wget https://dcc.ligo.org/public/0171/P2000434/001/Produce-Figures.ipynb
# Out:
# --2021-04-09 22:47:21--  https://dcc.ligo.org/public/0171/P2000434/001/Produce-Figures.ipynb
# Resolving dcc.ligo.org (dcc.ligo.org)... 131.215.125.144
# Connecting to dcc.ligo.org (dcc.ligo.org)|131.215.125.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2355452 (2.2M)
# Saving to: ‘Produce-Figures.ipynb’
#
# 100%[======================================>] 2,355,452   --.-K/s   in 0.03s
#
# 2021-04-09 22:47:21 (68.2 MB/s) - ‘Produce-Figures.ipynb’ saved [2355452/2355452]

# %%
# !wget https://dcc.ligo.org/public/0171/P2000434/001/injections_O1O2an_spin.h5
# Out:
# --2021-04-09 22:47:42--  https://dcc.ligo.org/public/0171/P2000434/001/injections_O1O2an_spin.h5
# Resolving dcc.ligo.org (dcc.ligo.org)... 131.215.125.144
# Connecting to dcc.ligo.org (dcc.ligo.org)|131.215.125.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 614408 (600K)
# Saving to: ‘injections_O1O2an_spin.h5’
#
# 100%[======================================>] 614,408     --.-K/s   in 0.01s
#
# 2021-04-09 22:47:42 (61.0 MB/s) - ‘injections_O1O2an_spin.h5’ saved [614408/614408]

# %%
# !pip install git-lfs

# %%
# !git clone https://github.com/farr/EffectiveSpinMass.git
# Out:
# Cloning into 'EffectiveSpinMass'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 107 (delta 43), reused 93 (delta 29), pack-reused 0
# Receiving objects: 100% (107/107), 11.56 MiB | 10.18 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Filtering content: 100% (17/17), 75.26 MiB | 44.14 MiB/s, done.

# %%
# !git clone https://github.com/simonamiller/LIGO-GWTC1-chieff-analysis.git
# Out:
# Cloning into 'LIGO-GWTC1-chieff-analysis'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 78 (delta 24), reused 16 (delta 2), pack-reused 28
# Unpacking objects: 100% (78/78), done.

# %%
import astropy.cosmology as cosmo
from astropy.cosmology import Planck15
import astropy.units as u
import h5py
import seaborn as sns

# %%
with h5py.File('O3aSensitivity/o3a_bbhpop_inj_info.hdf', 'r') as f:
    print(list(f.keys()))
    print(list(f['injections'].keys()))
    print(list(f.attrs.items()))
# Out:
# ['injections']
# ['distance', 'gps_time_int', 'ifar_gstlal', 'ifar_pycbc_bbh', 'ifar_pycbc_full', 'mass1_source', 'mass2_source', 'optimal_snr_h', 'optimal_snr_l', 'redshift', 'sampling_pdf', 'spin1z', 'spin2z']
# [('N_exp/R(z=0)', 979.0426119706958), ('analysis_time_s', 15843600), ('max_redshift', 2.3), ('n_accepted', 156878), ('n_rejected', 76825621), ('surveyed_VT_Gpc_yr', 167.60465680916), ('total_generated', 76982499)]
