# %% [markdown]
# ## Imports

# %%
from helper_functions import *
from plots import *

xp = gwpop.cupy_utils.xp

# %%
luminosity_distances = np.linspace(1, 50000, 1000)
redshifts = np.array([cosmo.z_at_value(Planck15.luminosity_distance, 
                                                   dl * u.Mpc) for dl in luminosity_distances])
dl_to_z = interp1d(luminosity_distances, redshifts)
luminosity_prior = luminosity_distances ** 2
dz_ddl = np.gradient(redshifts, luminosity_distances)

redshift_prior = interp1d(redshifts, luminosity_prior / dz_ddl / (1 + redshifts))

# %% [markdown]
# ### Posteriors

# %%
## Only run this to load posteriors if they have already been calculated

posteriors = list()
for filename in glob.glob('../processed_samples/OverallPosteriors/*'):
    _posterior = pd.read_csv(filename)
    posteriors.append(_posterior)

# %%
BOUNDS = dict(
    mass_1=(2, 100),
    mass_ratio=(0, 1),
    a_1=(0, 1),
    a_2=(0, 1),
    cos_tilt_1=(-1, 1),
    cos_tilt_2=(-1, 1),
    redshift=(0, 2.3))

PRIOR_VOLUME = (
    (BOUNDS["mass_1"][1] - BOUNDS["mass_1"][0]) ** 2
    * (BOUNDS["a_1"][1] - BOUNDS["a_1"][0])
    * (BOUNDS["a_2"][1] - BOUNDS["a_2"][0])
    * (BOUNDS["cos_tilt_1"][1] - BOUNDS["cos_tilt_1"][0])
    * (BOUNDS["cos_tilt_2"][1] - BOUNDS["cos_tilt_2"][0])) / 2

for posterior in posteriors:
    del posterior["chi_eff"]
    del posterior["chi_p"]
    del posterior["joint_prior"]
    posterior["spin_prior"] = 1/4
    posterior["mass_spin_prior"] = (posterior["mass_1"] * (1 + posterior["redshift"])**2)/PRIOR_VOLUME
    posterior["redshift_prior"] = redshift_prior(posterior['redshift'])

# %% [markdown]
# ### Default Model with selection effects

# %%
model = bilby.hyper.model.Model([mass.SinglePeakSmoothedMassDistribution(),
                                 spin.iid_spin_default,
                                 redshift.PowerLawRedshift()])

for posterior in posteriors:
    posterior["prior"] = posterior["mass_spin_prior"] * posterior["redshift_prior"]

# %%
def load_vt():
    vt_file = '../Sensitivity/O3aSensitivity/o3a_bbhpop_inj_info.hdf'
    vt_model = Model([mass.SinglePeakSmoothedMassDistribution(), 
                      redshift.PowerLawRedshift()])
    vt_func = injection_resampling_vt_mass_redshift
    
    return vt_func(vt_file, model = vt_model)

selection_function = load_vt()
# Out:
# 10:09 bilby INFO    : Loading VT data from ../Sensitivity/O3aSensitivity/o3a_bbhpop_inj_info.hdf.

# %%
def prior_conversion1(parameters):
    mu = parameters["mu_chi"]
    var = parameters["sigma_chi"]
    parameters["alpha_chi"] = (mu ** 2 * (1 - mu) - mu * var) / var
    parameters["beta_chi"] = (mu * (1 - mu) ** 2 - (1 - mu) * var) / var
    return parameters

def prior_conversion2(parameters):
    mu = parameters["mu_chi"]
    var = parameters["sigma_chi"]
    added_keys = pd.DataFrame()
    parameters["alpha_chi"] = (mu ** 2 * (1 - mu) - mu * var) / var
    parameters["beta_chi"] = (mu * (1 - mu) ** 2 - (1 - mu) * var) / var
    added_keys["alpha_chi"] = parameters["alpha_chi"]
    added_keys["beta_chi"] = parameters["beta_chi"]
    return parameters, added_keys

# %%
priors = PriorDict(conversion_function = prior_conversion1)

# rate 
priors["rate"] = LogUniform(minimum=1e-1, maximum=1e3, latex_label=r'$R$', boundary="reflective")

# mass
priors["alpha"] = Uniform(minimum=-4., maximum=12., latex_label=r'$\alpha$', boundary='reflective')
priors["beta"] = Uniform(minimum=-4., maximum=12., latex_label=r'$\beta_q$')
priors['delta_m'] = Uniform(minimum=0., maximum=10., latex_label=r'$\delta_m$ $[M_\odot]$')
priors["mmin"] = Uniform(minimum=2., maximum=10., latex_label=r'$m_\mathrm{min}$ $[M_\odot]$')
priors['mmax'] = Uniform(minimum=30., maximum=100., latex_label=r'$m_\mathrm{max}$ $[M_\odot]$')
priors['lam'] = Uniform(minimum=0., maximum=1., latex_label=r'$\lambda_\mathrm{peak}$')
priors['mpp'] = Uniform(minimum=20., maximum=50., latex_label=r'$\mu_m$ $[M_\odot]$')
priors['sigpp'] = Uniform(minimum=0.4, maximum=10., latex_label=r'$\sigma_m$ $[M_\odot]$')

# spin magnitude 
priors["mu_chi"] = Uniform(minimum = 0, maximum = 1, latex_label = r'$\mu_\chi$')
priors["sigma_chi"] = Uniform(minimum = 0, maximum = 0.25, latex_label = r'$\sigma^2_\chi$')
priors["amax"] = 1
priors["alpha_chi"] = Constraint(minimum = 1, maximum = 1e5)
priors["beta_chi"] = Constraint(minimum = 1, maximum = 1e5)

# spin orientation
priors["xi_spin"] = Uniform(minimum = 0, maximum = 1, latex_label=r'$\zeta$')
priors["sigma_spin"] = Uniform(minimum = 0.01, maximum = 4, latex_label=r'$\sigma_t$')

# redshift
priors["lamb"] = Uniform(minimum=-6, maximum=6, name='lamb', latex_label="$\\lambda_z$")

# %%
likelihood = gwpop.hyperpe.RateLikelihood(posteriors = posteriors, 
                                          hyper_prior = model,
                                          conversion_function = prior_conversion2,
                                          selection_function = selection_function)

# %%
likelihood.parameters.update(priors.sample())

# %%
result = bilby.run_sampler(likelihood = likelihood, priors = priors, sampler='dynesty', 
                           nlive = 1000, label='default_spin_mass_redshift_vt', 
                           outdir = 'Results/default_spin_mass_redshift_vt', clean = True)
# Out:
# 10:09 bilby INFO    : Running for label 'default_spin_mass_redshift_vt', output will be saved to 'Results/default_spin_mass_redshift_vt'
# 10:09 bilby INFO    : Search parameters:
# 10:09 bilby INFO    :   rate = LogUniform(minimum=0.1, maximum=1000.0, name=None, latex_label='$R$', unit=None, boundary='reflective')
# 10:09 bilby INFO    :   alpha = Uniform(minimum=-4.0, maximum=12.0, name=None, latex_label='$\\alpha$', unit=None, boundary='reflective')
# 10:09 bilby INFO    :   beta = Uniform(minimum=-4.0, maximum=12.0, name=None, latex_label='$\\beta_q$', unit=None, boundary=None)
# 10:09 bilby INFO    :   delta_m = Uniform(minimum=0.0, maximum=10.0, name=None, latex_label='$\\delta_m$ $[M_\\odot]$', unit=None, boundary=None)
# 10:09 bilby INFO    :   mmin = Uniform(minimum=2.0, maximum=10.0, name=None, latex_label='$m_\\mathrm{min}$ $[M_\\odot]$', unit=None, boundary=None)
# 10:09 bilby INFO    :   mmax = Uniform(minimum=30.0, maximum=100.0, name=None, latex_label='$m_\\mathrm{max}$ $[M_\\odot]$', unit=None, boundary=None)
# 10:09 bilby INFO    :   lam = Uniform(minimum=0.0, maximum=1.0, name=None, latex_label='$\\lambda_\\mathrm{peak}$', unit=None, boundary=None)
# 10:09 bilby INFO    :   mpp = Uniform(minimum=20.0, maximum=50.0, name=None, latex_label='$\\mu_m$ $[M_\\odot]$', unit=None, boundary=None)
# 10:09 bilby INFO    :   sigpp = Uniform(minimum=0.4, maximum=10.0, name=None, latex_label='$\\sigma_m$ $[M_\\odot]$', unit=None, boundary=None)
# 10:09 bilby INFO    :   mu_chi = Uniform(minimum=0, maximum=1, name=None, latex_label='$\\mu_\\chi$', unit=None, boundary=None)
# 10:09 bilby INFO    :   sigma_chi = Uniform(minimum=0, maximum=0.25, name=None, latex_label='$\\sigma^2_\\chi$', unit=None, boundary=None)
# 10:09 bilby INFO    :   xi_spin = Uniform(minimum=0, maximum=1, name=None, latex_label='$\\zeta$', unit=None, boundary=None)
# 10:09 bilby INFO    :   sigma_spin = Uniform(minimum=0.01, maximum=4, name=None, latex_label='$\\sigma_t$', unit=None, boundary=None)
# 10:09 bilby INFO    :   lamb = Uniform(minimum=-6, maximum=6, name='lamb', latex_label='$\\lambda_z$', unit=None, boundary=None)
# 10:09 bilby INFO    :   alpha_chi = Constraint(minimum=1, maximum=100000.0, name=None, latex_label=None, unit=None)
# 10:09 bilby INFO    :   beta_chi = Constraint(minimum=1, maximum=100000.0, name=None, latex_label=None, unit=None)
# 10:09 bilby INFO    :   amax = 1
# 10:09 bilby INFO    : Single likelihood evaluation took 3.432e-02 s
# 0it [00:00, ?it/s]
# 10:09 bilby INFO    : Using sampler Dynesty with kwargs {'bound': 'multi', 'sample': 'rwalk', 'verbose': True, 'periodic': None, 'reflective': None, 'check_point_delta_t': 600, 'nlive': 1000, 'first_update': None, 'walks': 100, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'enlarge': 1.5, 'bootstrap': None, 'vol_dec': 0.5, 'vol_check': 8.0, 'facc': 0.2, 'slices': 5, 'update_interval': 600, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7f8f009e2b80>>, 'dlogz': 0.1, 'maxiter': None, 'maxcall': None, 'logl_max': inf, 'add_live': True, 'print_progress': True, 'save_bounds': False, 'n_effective': None, 'maxmcmc': 5000, 'nact': 5}
# 10:09 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 10:09 bilby INFO    : Using dynesty version 1.0.1
# 10:09 bilby INFO    : Using the bilby-implemented rwalk sample method with ACT estimated walks
# 10:09 bilby INFO    : Generating initial points from the prior
# 10:21 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 10:31 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 10:42 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 10:52 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:03 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:13 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:23 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:34 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:44 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 11:54 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:05 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:15 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:25 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:35 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:46 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 12:56 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:06 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:16 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:26 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:37 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:47 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 13:57 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:08 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:18 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:28 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:38 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:48 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 14:59 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 15:09 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 15:19 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 15:30 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 15:40 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 15:51 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:01 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:11 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:22 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:32 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:42 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 16:53 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:03 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:13 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:24 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:34 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:45 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 17:55 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:06 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:16 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:27 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:37 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:47 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:57 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:08 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:18 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:28 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:39 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:49 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:59 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:10 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:20 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:30 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:40 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:51 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:01 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:12 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:22 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:32 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:42 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:53 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:03 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:13 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:24 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:34 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:44 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:55 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:05 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:15 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:26 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:36 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:46 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:56 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:07 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:17 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:27 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:37 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:48 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 00:58 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 01:09 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 01:19 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 01:30 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 01:40 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 01:50 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:01 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:11 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:22 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:32 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:43 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 02:53 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:04 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:14 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:25 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:35 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:46 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 03:56 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 04:07 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 04:17 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 04:28 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 04:39 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 04:49 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:00 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:10 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:20 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:31 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:42 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 05:52 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 06:03 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 06:13 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 06:23 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
# ...
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:05 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:05 bilby INFO    : Writing 196 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:16 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:16 bilby INFO    : Writing 190 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:27 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:27 bilby INFO    : Writing 214 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:38 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:38 bilby INFO    : Writing 224 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:48 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:48 bilby INFO    : Writing 324 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 18:59 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 18:59 bilby INFO    : Writing 373 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:10 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 19:10 bilby INFO    : Writing 430 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:21 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 19:21 bilby INFO    : Writing 484 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:32 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 19:32 bilby INFO    : Writing 575 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:43 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 19:43 bilby INFO    : Writing 689 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 19:54 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 19:54 bilby INFO    : Writing 614 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:05 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:05 bilby INFO    : Writing 740 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:16 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:16 bilby INFO    : Writing 676 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:27 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:27 bilby INFO    : Writing 851 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:38 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:38 bilby INFO    : Writing 988 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:48 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:48 bilby INFO    : Writing 1172 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 20:59 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 20:59 bilby INFO    : Writing 1310 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:10 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 21:10 bilby INFO    : Writing 1682 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:21 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 21:21 bilby INFO    : Writing 1963 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:32 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 21:32 bilby INFO    : Writing 2268 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:43 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 21:43 bilby INFO    : Writing 2753 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 21:54 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 21:54 bilby INFO    : Writing 3218 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:05 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:05 bilby INFO    : Writing 3798 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:16 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:16 bilby INFO    : Writing 4434 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:27 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:27 bilby INFO    : Writing 5166 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:37 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:37 bilby INFO    : Writing 6251 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:48 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:48 bilby INFO    : Writing 6740 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 22:59 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 22:59 bilby INFO    : Writing 6796 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:10 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 23:10 bilby INFO    : Writing 6803 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:11 bilby INFO    : Written checkpoint file Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_resume.pickle
# 23:12 bilby INFO    : Writing 6735 current samples to Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_samples.dat
# /home/deepnika.jain/anaconda3/envs/gwspin/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 23:12 bilby INFO    : Sampling time: 1 day, 13:00:32.345216
# 23:12 bilby INFO    : Summary of results:
# nsamples: 24593
# ln_noise_evidence:    nan
# ln_evidence:    nan +/-  0.184
# ln_bayes_factor: -987.761 +/-  0.184

# %%
result.plot_corner(parameters = ('xi_spin', 'mu_chi', 'sigma_chi', 'sigma_spin'))

# %%
overlayed_plot_default("Results/O3a_LIGO_default_results/O3a_LIGO_default_results.json", 
                       "Results/default_spin_mass_redshift_vt/default_spin_mass_redshift_vt_result.json", 
                       "default_spin_mass_redshift_vt", save = True)
# Out:
# xi_spin mu_chi 0.02609994763971855
# xi_spin sigma_chi 0.02327091797992632
# xi_spin sigma_spin 0.04342188749774395
# mu_chi sigma_chi 0.011227200943100958
# mu_chi sigma_spin 0.020949163100760417
# sigma_chi sigma_spin 0.018678438094795795
# /home/deepnika.jain/O3a/Default/plots.py:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i))
# /home/deepnika.jain/O3a/Default/plots.py:53: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i + (j+1)*ndim))
# xi_spin mu_chi 0.023010715415823852
# xi_spin sigma_chi 0.019555142689028117
# xi_spin sigma_spin 0.037051562426775875
# /home/deepnika.jain/O3a/Default/plots.py:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i))
# /home/deepnika.jain/O3a/Default/plots.py:53: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i + (j+1)*ndim))
# mu_chi sigma_chi 0.00966171353729422
# mu_chi sigma_spin 0.0183062628572655
# /home/deepnika.jain/O3a/Default/plots.py:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i))
# /home/deepnika.jain/O3a/Default/plots.py:53: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i + (j+1)*ndim))
# sigma_chi sigma_spin 0.015557168728031291
# /home/deepnika.jain/O3a/Default/plots.py:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(ndim,ndim,int(1+(ndim+1)*i))

# %%
result.plot_corner(parameters = ('alpha', 'beta', 'mmin', 'mmax', 'lam', 'mpp', 'sigpp', 'delta_m'))
